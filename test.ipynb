# %%
import pandas as pd

# %%
df = pd.read_csv('./enet_inner_layer_0_90472_90473_2_1.csv', header=None)

# %%
diff = abs(df.iloc[0] - df.iloc[1])
#print(df.loc[:, abs(df.iloc[0] - df.iloc[1]) > 20])
for i in range(1, 31):
    count = (diff == i).sum()
    if count > 0:
        print(f"Difference of {i}: {count}")
# Out:
# Difference of 1: 482
# Difference of 2: 136
# Difference of 3: 56
# Difference of 4: 50
# Difference of 5: 16
# Difference of 6: 12
# Difference of 7: 9
# Difference of 8: 4
# Difference of 15: 8
# Difference of 17: 8
# Difference of 18: 4
# Difference of 20: 4
# Difference of 21: 4
# Difference of 22: 4
